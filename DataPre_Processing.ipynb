# %% [markdown]
# <a href="https://colab.research.google.com/github/7009soham/MLKJSIM/blob/main/DataPre_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
weather = pd.read_csv("WeatherData.csv")
weather
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2021         32.0        6.0    Rain
# 1  01-04-2021          NaN        9.0   Sunny
# 2  01-05-2021         28.0        NaN    Snow
# 3  01-06-2021          NaN        7.0     NaN
# 4  01-07-2021         32.0        NaN    Rain
# 5  01-08-2021          NaN        NaN   Sunny
# 6  01-09-2021          NaN        NaN     NaN
# 7  01-10-2021         34.0        8.0  Cloudy
# 8  01-11-2021         40.0       12.0   Sunny

# %%
weather.fillna({'temperature':0,'windspeed':0,'event':"No Event",})
#weather['event'].fillna("No")
# Out:
#           day  temperature  windspeed     event
# 0  01-01-2021         32.0        6.0      Rain
# 1  01-04-2021          0.0        9.0     Sunny
# 2  01-05-2021         28.0        0.0      Snow
# 3  01-06-2021          0.0        7.0  No Event
# 4  01-07-2021         32.0        0.0      Rain
# 5  01-08-2021          0.0        0.0     Sunny
# 6  01-09-2021          0.0        0.0  No Event
# 7  01-10-2021         34.0        8.0    Cloudy
# 8  01-11-2021         40.0       12.0     Sunny

# %%
#Forward Fill
weather.ffill()
weather.fillna(method="ffill")
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2021         32.0        6.0    Rain
# 1  01-04-2021         32.0        9.0   Sunny
# 2  01-05-2021         28.0        9.0    Snow
# 3  01-06-2021         28.0        7.0    Snow
# 4  01-07-2021         32.0        7.0    Rain
# 5  01-08-2021         32.0        7.0   Sunny
# 6  01-09-2021         32.0        7.0   Sunny
# 7  01-10-2021         34.0        8.0  Cloudy
# 8  01-11-2021         40.0       12.0   Sunny

# %%
#BackWard Fill
weather.bfill()
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2021         32.0        6.0    Rain
# 1  01-04-2021         28.0        9.0   Sunny
# 2  01-05-2021         28.0        7.0    Snow
# 3  01-06-2021         32.0        7.0    Rain
# 4  01-07-2021         32.0        8.0    Rain
# 5  01-08-2021         34.0        8.0   Sunny
# 6  01-09-2021         34.0        8.0  Cloudy
# 7  01-10-2021         34.0        8.0  Cloudy
# 8  01-11-2021         40.0       12.0   Sunny

# %%
import warnings
weather1 = weather.interpolate()
weather1
# Out:
# <ipython-input-24-bad804308dd6>:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   weather1 = weather.interpolate()
#           day  temperature  windspeed   event
# 0  01-01-2021    32.000000       6.00    Rain
# 1  01-04-2021    30.000000       9.00   Sunny
# 2  01-05-2021    28.000000       8.00    Snow
# 3  01-06-2021    30.000000       7.00     NaN
# 4  01-07-2021    32.000000       7.25    Rain
# 5  01-08-2021    32.666667       7.50   Sunny
# 6  01-09-2021    33.333333       7.75     NaN
# 7  01-10-2021    34.000000       8.00  Cloudy
# 8  01-11-2021    40.000000      12.00   Sunny

# %%
weather.dropna()
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2021         32.0        6.0    Rain
# 7  01-10-2021         34.0        8.0  Cloudy
# 8  01-11-2021         40.0       12.0   Sunny
